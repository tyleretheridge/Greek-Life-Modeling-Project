# %% [markdown]
# # Modeling Duke University Students' Involvement in Greek Life

# %% [markdown]
# Tyler Etheridge
#
# The purpose of this project is to create a model that can predictively classify students as being involved in Greek Life at Duke University based on information about their lives prior to university enrollment.
# The data was obtained from [this repository](https://github.com/Chrissymbeck/Greek-Life-Demographics), featured in [an article published by the independent university press *The Chronicle*](https://www.dukechronicle.com/article/2018/01/is-greek-life-at-duke-as-homogenous-as-you-think) in January 2018.

# %% [markdown]
# # Data Importing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Ignores warnings caused by visualization libraries' dependencies being set for deprecation
import warnings
with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
# Import Data
# Pass list of clean names for overwriting
column_names = ['greek_council', 'greek_organization', 'city', 
                'state', 'country','latitude', 'longitude', 
                'free_lunch_percent','public_private', 'domestic_school',
                'boarding', 'religion','school_gender', 'tuition','sports_team',
                'scholarship']

df = pd.read_csv('/home/tyler/Downloads/duke_greek.csv',header=0, names=column_names)

# %% [markdown]
# # Data Exploration

# %%
# View data and shape
print("Dataframe shape:", df.shape)
df.head()
# Out:
# Dataframe shape: (1739, 16)
#   greek_council greek_organization         city           state  \
# 0          None               None     Accokeek        Maryland
# 1          None               None      Advance  North Carolina
# 2          None               None        Ajman             NaN
# 3          None               None      Alameda      California
# 4          None               None  Albuquerque      New Mexico
#
#                 country   latitude   longitude  free_lunch_percent  \
# 0         United States  38.667617  -77.028309  Data not available
# 1         United States  35.941248  -80.409222          0.34741523
# 2  United Arab Emirates  25.509129   55.361907                 NaN
# 3         United States  37.609029 -121.899142              0.2268
# 4         United States  35.084103 -106.650985  Data not available
#
#   public_private domestic_school boarding      religion school_gender  \
# 0        private        Domestic      Day     Episcopal         Co-Ed
# ...

# %% [markdown]
# ## pandas profiling

# %% [markdown]
# pandas profiling provides thorough yet condensed overview of the data, siginficantly reducing the need for repeated attribute exploration code by presenting these attributes in an interactive document format.

# %%
from IPython.display import IFrame
IFrame('http://stackoverflow.org', width=700, height=350)
from pandas_profiling import ProfileReport 
profile = ProfileReport(df, minimal=True).to_notebook_iframe()
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.6.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# Generate a map to view geographical distribution of students, colored by council involvement
import plotly.express as px

fig = px.scatter_mapbox(
    df, 
    lat='latitude', 
    lon='longitude', 
    color='greek_council', 
    opacity=0.8)
fig.update_layout(mapbox_style='open-street-map')
fig.show()

# Map is zoomed in by default, zoom out to view countries
# Out:
# <div>
#
#
#             <div id="8d6f9cd9-2396-4d71-b7e9-9a019ec1df38" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8d6f9cd9-2396-4d71-b7e9-9a019ec1df38")) {
#                     Plotly.newPlot(
#                         '8d6f9cd9-2396-4d71-b7e9-9a019ec1df38',
# ...

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# **Null Value Resolution**
# Data regarding high school financials or other statistics is frequently omitted in the case of international and private high schools due to lack of information accessibility or relevance. In these specific cases, the original authors of the dataset use the phrase "Data not available" to signal this in conjunction with `np.NaN` for other missing values.
#
# The presence of this string prevents casting columns to the float datatype, so it must be reconciled before feature engineering and imputation. "Data not available" will be globally replaced with `np.NaN` and treated as such. These values will be imputed like all other missing values in the modeling pipeline.

# %%
def feature_engineering(X):
    
    # Avoid warnings from changes to original data structure
    df = X.copy()
    
    # Replace "Data not available" with np.Nan
    df = df.replace({"Data not available" : np.NaN})
        
    # Convert 'tuition' to float
    df['tuition'] = df['tuition'].str.replace(",","").astype(float)
        
    # Convert 'free_lunch_percent' to float
    df['free_lunch_percent'] = df['free_lunch_percent'].astype(float)
        
    # Consolidate Sorority/Fraternity and map to binary classification
    df['greek'] = df['greek_council'].map({'None':'No', 'Sorority':'Yes', 'Fraternity':'Yes'})
    
    # Fix errors in 'Sports Team', Reengineer to genderless
    df['sports_team'] = df['sports_team'].str.replace('Fooball', 'Football')
    df['sports'] = df['sports_team']
    df['sports'] = df['sports'].str.lstrip("Men's ")
    df['sports'] = df['sports'].str.lstrip("Women's ")
    df['sports'] = df['sports'].str.replace('restling', 'Wrestling')
    
    return df

# %%
# Execute feature engineering function
df = feature_engineering(df)

# Ensure proper dtypes were cast
df.dtypes
# Out:
# greek_council          object
# greek_organization     object
# city                   object
# state                  object
# country                object
# latitude              float64
# longitude             float64
# free_lunch_percent    float64
# public_private         object
# domestic_school        object
# boarding               object
# religion               object
# school_gender          object
# tuition               float64
# sports_team            object
# scholarship            object
# greek                  object
# sports                 object
# dtype: object

# %%
# Ensure proper string edits occurred
df['sports'].value_counts()
# Out:
# None            1561
# Football          24
# Track             23
# Soccer            20
# Lacrosse          20
# Fencing           16
# Swimming          14
# Baseball          13
# Rowing            13
# Wrestling          8
# Basketball         7
# Field Hockey       7
# Golf               5
# Tennis             4
# Volleyball         4
# Name: sports, dtype: int64

# %%
# Check new target feature mapping
df['greek'].value_counts()
# Out:
# No     1151
# Yes     588
# Name: greek, dtype: int64

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Data Subsetting

# %% [markdown]
# Create train, validation, and test subsets of data for modeling by using train_test_split() twice

# %%
from sklearn.model_selection import train_test_split

# %%
# Split df into train and test sets
train, test = train_test_split(df, test_size=0.20, random_state=20)
train.shape, test.shape
# Out:
# ((1391, 18), (348, 18))

# %%
# Split train into train and validation sets
train, val = train_test_split(train, random_state=20)
train.shape, val.shape
# Out:
# ((1043, 18), (348, 18))

# %% [markdown]
# **Feature Exclusions**:
# `greek`: Classification target
# `greek_council`: Re-engineered to binary classification, `greek` is used instead as target
# `greek_organization`: Would introduce data leakage
# `city`: Redundant with latitude and longitude
# `state`: Redundant with latitude and longitude
# `country`: Redundant with latitude and longitude

# %% [markdown]
# **Data Redundancy**
# Not only do the features `city`, `state`, and `country` contain the same information as `latitude` and `longitude`, but they also hold the information in a format that is not numerical or in a geographically consistent system. All city, state, and country location information is inherently held in the corresponding latitude and longitude coordinates. Attempting to encode these columns would only result in a worse latitude/longitude coordinate system that is not geographically consistent.
#
# **Data Leakage**
# The data in the `greek_organization` feature can not be used for modeling purposes. The values in this column are specific subdivisons of the original values in `greek_council`. Including this information would directly inform the model of the student classification, introducing data leakage.

# %%
# Organize data into feature matrices and target vectors

# Feature matrix exclusions
drop = ['greek', 'greek_council', 'greek_organization', 
        'city', 'state', 'country']

# Target
target = 'greek'

# Train set
X_train = train.drop(columns=drop)
y_train = train[target]

# Validation set
X_val = val.drop(columns=drop)
y_val = val[target]

# Test set
X_test = test.drop(columns=drop)
y_test = test[target]

# %% [markdown]
# ## Majority Class Baseline Model

# %%
# Get normalized values for each class entry
train['greek'].value_counts(normalize=True)
# Out:
# No     0.656759
# Yes    0.343241
# Name: greek, dtype: float64

# %% [markdown]
# ## Random Forest Model

# %%
import category_encoders as ce
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from scipy.stats import randint

# %% [markdown]
# **Model in pipeline**

# %%
# Create tree based model sklearn pipeline
tree_pipeline = make_pipeline(
    # Encode objects/categoricals
    ce.OrdinalEncoder(),
    # Impute null values
    SimpleImputer(strategy='median'),
    # Model using RandomForest
    RandomForestClassifier(random_state=20, n_jobs=-1)
)

# Create hyperparameter dictionary for RandomizedSearchCV()
param_distributions = {
    'simpleimputer__strategy': ['mean', 'median'],
    'randomforestclassifier__n_estimators': randint(50, 500),
    'randomforestclassifier__max_depth': [15, 20, 25, 30, None],
}

# Use RandomizedSearchCV() to optimize hyperparameters
# Instantiate the search object
search = RandomizedSearchCV(
    tree_pipeline,
    param_distributions=param_distributions,
    n_iter=20,
    cv=5,
    scoring='accuracy',
    verbose=0,
    return_train_score=True,
    n_jobs=-1,
    random_state=20
)

# Perform tuning
search.fit(X_train, y_train);

# %%
# Get optimized parameters
print('Best hyperparameters', search.best_params_)
print('Cross-validation Accuracy', search.best_score_)
# Out:
# Best hyperparameters {'randomforestclassifier__max_depth': 15, 'randomforestclassifier__n_estimators': 155, 'simpleimputer__strategy': 'median'}
# Cross-validation Accuracy 0.6624907986750092

# %%
# Save optimized pipeline
tree_pipeline = search.best_estimator_

# %% [markdown]
# **Model outside of pipeline**
#
# Many visualization libraries do not yet support scikit-learn's pipeline, requiring the model be reconstructed outside of the pipeline.

# %%
# Instantiate encoder and fit
encoder = ce.OrdinalEncoder()
X_train_encoded = encoder.fit_transform(X_train)
X_val_encoded = encoder.transform(X_val)

# Instantiate imputer and fit
imputer = SimpleImputer(strategy='median')
X_train_imputed = imputer.fit_transform(X_train_encoded)
X_val_imputed = imputer.transform(X_val_encoded)


# Instantiate Model using params from tuning
model = tree_pipeline['randomforestclassifier']

# Model Fit
model.fit(X_train_imputed, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=15, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=155,
#                        n_jobs=-1, oob_score=False, random_state=20, verbose=0,
#                        warm_start=False)

# %% [markdown]
# ## Random Forest Metrics

# %% [markdown]
# Although not used to evaluate the model's performance, train accuracy is included to function as a rudimentary overfitting signal.

# %%
# Train accuracy score
print('Train Accuracy:', tree_pipeline.score(X_train, y_train))
# Out:
# Train Accuracy: 0.9309683604985618

# %%
from sklearn.metrics import roc_auc_score

# %%
# Create function to return validation metrics
def val_metrics(pipeline, X_val, y_val):
    """Calculates accuracy and roc auc scores, then prints"""
    
    # Get validation accuracy
    val_accuracy = pipeline.score(X_val, y_val)
    # Get list of predicted probabilities
    y_pred_proba = pipeline.predict_proba(X_val)[:,-1]
    # Calculate ROC AUC Score
    val_roc = roc_auc_score(y_val, y_pred_proba)
    
    # Print
    print('Validation Accuracy Score: ', val_accuracy)
    print('Validation ROC AUC: ', val_roc)

# %%
# Execute val_metrics to get accuracy and ROC AUC for validation set
val_metrics(tree_pipeline, X_val, y_val)
# Out:
# Validation Accuracy Score:  0.6637931034482759
# Validation ROC AUC:  0.6572033898305084

# %% [markdown]
# ## Random Forest Model Visualizations

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import plot_confusion_matrix
# Matplotlib settings
plt.rcParams['figure.dpi'] = 150
plt.style.use('default')

# Plot confusion matrix
plot_confusion_matrix(
    tree_pipeline, 
    X_val, 
    y_val, 
    values_format='.0f', 
    xticks_rotation='vertical'
)
plt.show()

# %% [markdown]
# ### Permutation Importances

# %%
# Permutation importances
import eli5
from eli5.sklearn import PermutationImportance

# Instantiate
permuter = PermutationImportance(
    model,
    scoring='accuracy',
    n_iter=5,
    random_state=20
)

permuter.fit(X_val_imputed, y_val);

# %%
# Set column names to list
feature_names = X_val.columns.tolist()

#Print Permutation Importances
eli5.show_weights(
    permuter,
    top=None,
    feature_names=feature_names
)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0161
#
#                     &plusmn; 0.0059
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 religion
#             </td>
# ...

# %% [markdown]
# ### 1 Feature PDP - Tuition

# %%
# PDP can't handle NaN values, so X_val must be encoded then imputed
# PDP also requires a DataFrame, so the imputed X_val array is recast to a DataFrame
X_val_encoded_df = pd.DataFrame(data=X_val_imputed, columns=X_val.columns)

# %%
# 1 feature partial dependence plot
from pdpbox.pdp import pdp_isolate, pdp_plot
from pdpbox import pdp

# Set feature to analyze partial dependence
feature = 'tuition'

# Create isolated object with attributes
pdp_dist = pdp_isolate(
    # Regressor used
    model=model,
    # Current trend is using validate set here
    dataset=X_val_encoded_df,
    # List of other features to freeze
    model_features=X_val.columns,
    # Analyzed feature from abovev
    feature=feature
)

# %%
# Create Partial Dependency Plot
pdp_plot(pdp_dist, feature);
plt.xlim(0,40000)
plt.show()

# %% [markdown]
# This Partial Dependency Plot for `tuition` shows that as the tuition of high school increases, the RandomForestClassifier model increases its predicition probability for the student to be involved in Greek Life.
#
# Although the graph begins to decline near the 40,000 dollar tuition threshold, this is not relevant because there are only a handful of students who make up the population with tuition that high, and the model is not trained on that range.

# %% [markdown]
# # Linear Model

# %%
# Create pipeline
log_pipeline = make_pipeline(
    # Encode object/categoricals
    ce.OrdinalEncoder(),
    # Impute null values
    SimpleImputer(strategy='median'),
    # Scale Data
    StandardScaler(),
    # Model using LogisticRegression
    LogisticRegression(solver='lbfgs',n_jobs=-1, multi_class='ovr')
)

# Fit the pipeline
log_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('ordinalencoder',
#                  OrdinalEncoder(cols=['public_private', 'domestic_school',
#                                       'boarding', 'religion', 'school_gender',
#                                       'sports_team', 'scholarship', 'sports'],
#                                 drop_invariant=False, handle_missing='value',
#                                 handle_unknown='value',
#                                 mapping=[{'col': 'public_private',
#                                           'data_type': dtype('O'),
#                                           'mapping': public         1
# private        2
# NaN            3
# Home School    4
# dtype: int...
#                                verbose=0)),
#                 ('standardscaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('logisticregression',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
# ...

# %% [markdown]
# **Model Coefficients**

# %%
# Extract fitted model from pipeline
model = log_pipeline['logisticregression']

# Get array of coefficients
coef = np.squeeze(model.coef_)

# %%
# Print coefficients with corresponding features
features = X_train.columns.tolist()
log_coefficients = pd.Series(coef, features)
print(log_coefficients.to_string())
# Out:
# latitude              0.045396
# longitude            -0.269428
# free_lunch_percent   -0.176098
# public_private       -0.150409
# domestic_school      -0.043948
# boarding             -0.209709
# religion             -0.040762
# school_gender         0.118768
# tuition               0.514805
# sports_team          -0.500026
# scholarship          -0.163407
# sports                0.356863

# %% [markdown]
# ## Linear Model Metrics

# %%
# Train accuracy score
print('Train Accuracy:', log_pipeline.score(X_train, y_train))
# Out:
# Train Accuracy: 0.6692233940556088

# %%
# Validation Metrics
val_metrics(log_pipeline, X_val, y_val)
# Out:
# Validation Accuracy Score:  0.6810344827586207
# Validation ROC AUC:  0.6624539425202652

# %% [markdown]
# ## Linear Model Visualizations

# %% [markdown]
# ### Confusion Matrix

# %%
# Plot Confusion Matrix
plt.style.use('default')
plot_confusion_matrix(
    log_pipeline,
    X_val,
    y_val,
    values_format='.0f',
    xticks_rotation='vertical'
)
plt.show()

# %% [markdown]
# ### Model Coefficients

# %%
# Plot coefficients as a horizontal bar plot
plt.style.use('fivethirtyeight')
log_coefficients.sort_values().plot.barh(color='#F3786D')
plt.xlim(-0.75,0.75)
plt.title("Linear Model Coefficients",fontsize=14)
plt.yticks(fontsize=11, fontweight='bold')
plt.show()

# %% [markdown]
# # Test Set Metrics

# %%
from sklearn.metrics import accuracy_score

# %%
def test_metrics(model_name, pipeline, X_test, y_test):
    """Calculates test accuracy, then prints.
    model_name is a string."""
    
    # Calculate y_pred for test set
    y_pred = pipeline.predict(X_test)
    # Calculate accuracy
    acc = accuracy_score(y_test, y_pred)
    # Print
    print(model_name +' model test accuracy: ', acc)

# %% [markdown]
# **RandomForestClassifier**

# %%
test_metrics("RandomForestClassifier", tree_pipeline, X_test, y_test)
# Out:
# RandomForestClassifier model test accuracy:  0.6839080459770115

# %% [markdown]
# **LogisticRegression**

# %%
test_metrics("LogisticRegression", log_pipeline, X_test, y_test)
# Out:
# LogisticRegression model test accuracy:  0.7097701149425287

# %% [markdown]
# Both the linear and tree based model have validation and test accuracies higher than that of the majority class baseline. The linear model averages about 3% more accurate; however, it is in some ways held back by it's inflexibility with encoding schemes that may prove better suited for the tree based model if the data's horizon's were broader.
